# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing import sequence
from tensorflow.keras.models import load_model

# %%
# Load the IMDB dataset
word_index = imdb.get_word_index()
reverse_word_index = {value: key for key, value in word_index.items()}

# %%
model = load_model('simple_rnn_imdb.h5')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  embedding (Embedding)       (None, 500, 256)          2560000
#
#  simple_rnn (SimpleRNN)      (None, 128)               49280
#
#  dense (Dense)               (None, 1)                 129
#
# ...
# Total params: 2609409 (9.95 MB)
# Trainable params: 2609409 (9.95 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.get_weights()
# Out:
# [array([[-0.02237386, -0.02998503, -0.02475624, ..., -0.04271014,
#          -0.01937005,  0.02206794],
#         [-0.01597161,  0.05431198, -0.06988595, ..., -0.0128747 ,
#           0.02571394,  0.02915674],
#         [-0.050195  ,  0.00903858, -0.00650613, ..., -0.03102132,
#          -0.02777856,  0.0163389 ],
#         ...,
#         [ 0.00049315,  0.06695035,  0.00570515, ..., -0.00744706,
#          -0.00934574, -0.01633957],
#         [ 0.03333471,  0.0194634 ,  0.03799333, ..., -0.02416103,
#           0.05478662, -0.04573381],
#         [ 0.06991792,  0.06901496,  0.06094634, ..., -0.07366873,
#           0.03962136,  0.05706684]], dtype=float32),
#  array([[-0.05982046, -0.05716059,  0.00429435, ..., -0.07415814,
#           0.08556231, -0.08150908],
#         [ 0.04844283, -0.15089688, -0.08866404, ..., -0.01833212,
#           0.04680187,  0.05328923],
#         [-0.05796888,  0.16505453, -0.10719523, ...,  0.04569383,
#           0.14676966, -0.14026743],
# ...

# %%
 # step 2
def decode_review(text):
    return ' '.join([reverse_word_index.get(i-3, '?') for i in text])

def preprocess_text(text):
    words = text.lower().split()
    encoded_review = [word_index.get(word,2)+3  for word in words]
    padded_review = sequence.pad_sequences([encoded_review], maxlen=500, padding='pre')
    return padded_review

# %%
 ## prediction function

 def predict_function(text):
    padded_review = preprocess_text(text)
    prediction = model.predict(padded_review)
    sentiment = 'positive' if prediction[0][0] > 0.5 else 'negative' 
    return sentiment, prediction[0][0]

# %%
# step 4

example_review = "I love this movie so much, it's amazing and I highly recommend it to everyone"
sentiment, scrore = predict_function(example_review)
# Out:
# 1/1 [==============================] - 0s 24ms/step

# %%
sentiment, scrore
# Out:
# ('positive', 0.99719644)

# %%
# step 4

example_review1 = "bad miserable movie"
sentiment1, scrore1 = predict_function(example_review1)
# Out:
# 1/1 [==============================] - 0s 34ms/step

# %%
sentiment1, scrore1
# Out:
# ('negative', 0.17287081)

# %%
# step 4

example_review2 = "nice movie"
sentiment, scrore = predict_function(example_review2)
# Out:
# 1/1 [==============================] - 0s 29ms/step

# %%
sentiment, scrore
# Out:
# ('positive', 0.7285228)

# %%
# step 4

example_review2 = "oh bad movie"
sentiment, scrore = predict_function(example_review2)
# Out:
# 1/1 [==============================] - 0s 28ms/step

# %%
sentiment, scrore
# Out:
# ('negative', 0.2892035)
